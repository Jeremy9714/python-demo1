# %% [markdown]
# ## 2. seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.sans-serif'] = 'SimHei'

df = pd.read_csv('../file/data.csv')
df.dropna(inplace=True)
df.info()
# 直方图
# sns.histplot(data=df, x='species')

# 核密度估计图
# sns.kdeplot(data=df, x='salary')

# 直方图 + 核密度估计图
# sns.histplot(data=df, x='salary', kde=True)

# 计数图
# sns.countplot(data=df, x='dept')

# 散点图
# 通过hue参数设置不同组别进行对比
# sns.scatterplot(data=df, x='species', y='dept', hue='salary')

# 条形图
# estimator指定推算子
# sns.barplot(data=df, x='species', y='salary', estimator='mean', errorbar=None)

# 箱线图
# sns.boxplot(data=df, x='species', y='salary')

# 成对图
# 用于显示多个变量之间关系的可视化工具. 可以展示多个变量之间的成对关系
sns.pairplot(data=df, hue='species')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5 non-null      int64
#  1   name        5 non-null      object
#  2   salary      5 non-null      int64
#  3   age         5 non-null      int64
#  4   dept        5 non-null      int64
#  5   species     5 non-null      object
# dtypes: int64(4), object(2)
# memory usage: 280.0+ bytes
